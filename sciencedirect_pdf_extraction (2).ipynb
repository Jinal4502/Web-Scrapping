# %% [markdown]
# ScienceDirect PDF Extraction and Download Script
# 1. Purpose
# This script automates the process of:
# Collecting article titles, Scopus IDs, and ScienceDirect links from multiple text/JSON files.
# Cleaning and normalizing those links to canonical ScienceDirect article URLs.
# Comparing extracted entries with an Excel file of SCOPUS IDs to remove unwanted records.
# Automating the download of PDFs from ScienceDirect using AppleScript on macOS with Safari.
# 2. Library Imports
# The script imports:
# requests, concurrent.futures – for HTTP requests and parallel processing.
# pandas, numpy, PyPDF2, tqdm – for data handling, PDF reading, and progress bars.
# selenium, undetected_chromedriver – for potential browser automation.
# subprocess, os, time, re, ast, OrderedDict – for system calls, timing, regex, and ordered dictionaries.
# 3. Reading and Cleaning Input Files
# get_pdf_links_with_titles(file_path) reads either:
# Plain text files with lines of ScopusID, Title, Link
# Or JSON files with {"title": {"scopus_id":…, "link":…}}
# Extracts the Scopus ID, article title, and ScienceDirect link.
# Normalizes each link to the canonical form:
# https://www.sciencedirect.com/science/article/pii/<PII>
# Returns a dictionary:
# {
#     "Article Title": {
#         "scopus_id": "SCOPUS_ID",
#         "link": "ScienceDirect URL"
#     },
#     ...
# }
# 4. Aggregating Multiple Files
# A list of input files (retrieved_links_140000–202947.txt) is iterated over.
# Each file is parsed into a dictionary and merged into all_pdfs.
# The total number of unique PDF/article entries is printed.
# 5. Removing Unwanted SCOPUS IDs
# Loads Remove_Scopus.xlsx into a pandas DataFrame.
# Extracts SCOPUS IDs from the second column using a regex (SCOPUS_ID:(\d+)).
# Compares these IDs with the batch of articles to flag and optionally remove overlaps.
# 6. Slicing Data into Batches
# slice_dict(d, start, end) is a helper to process large dictionaries in smaller chunks (e.g., 2,000 entries at a time).
# 7. Safari Automation (macOS Only)
# The script uses AppleScript via subprocess calls to automate Safari:
# science_direct_open_pdf_in_safari_and_save(pdf_url)
# Opens a ScienceDirect article in Safari, waits, clicks inside the page, and triggers the PDF download button using cliclick.
# clear_history()
# Clears Safari history periodically to prevent performance issues or popups.
# new_tab()
# Opens new Safari tabs as needed for large batches.
# This approach bypasses login barriers if you’re already authenticated in Safari with your institution credentials.
# 8. File Renaming and Organization
# After each download, the script:
# Checks the Downloads folder for newly added PDFs within the last 10 seconds.
# Cleans the article title for safe filenames (removes special characters).
# Renames the file as Title-ScopusID.pdf.
# Falls back to ScopusID.pdf if the title is too long for macOS.
# 9. Handling Missing Entries
# Compares SCOPUS IDs in the batch vs. already-downloaded PDFs in the output folder.
# Builds a missing_entries dict of articles still needing download.
# Loops through these and downloads them via Safari automation.
#
#
# ####10. Workflow Summary
# Input: Text/JSON files of ScienceDirect links and an Excel file of SCOPUS IDs to exclude.
# Parsing: Extract titles, SCOPUS IDs, and links; normalize URLs.
# Filtering: Remove unwanted SCOPUS IDs.
# Batching: Slice into manageable sets of 2,000 entries.
# Download Automation:
# Open article link in Safari.
# Click to download PDF.
# Rename and save into a target folder.
# Error Handling: Skip failures and continue; print issues for later review.
#
#
# 11. Key Advantages
# Scales: Handles hundreds of thousands of entries by batching.
# Institution Auth: Leverages Safari’s existing login session instead of handling cookies manually.
# Safe Filenames: Cleans and renames PDFs consistently.
# Recovery: Tracks missing SCOPUS IDs for re-runs.

# %% [markdown]
# ### Report on PDF Link Extraction and Automated Download Pipeline
#
# #### Overview
# This pipeline is designed to process large batches of metadata files containing Scopus IDs, article titles, and URLs (primarily from ScienceDirect), extract valid PDF links, filter and clean the data, and automate the downloading and renaming of PDF files using Safari on macOS. It also includes mechanisms to handle missing entries, avoid duplicates, and manage browser history to ensure smooth operation.
#
# ---
#
# #### 1. **PDF Link Extraction from Text Files**
#
# - **Function:** `get_pdf_links_with_titles(file_path)`
# - **Purpose:** Reads a text file where each line contains a Scopus ID, article title, and a URL separated by commas.
# - **Alternate Function:** A variant of `get_pdf_links_with_titles` reads for file containing 'pdf.sciencedirectassets.com', and fixes them accordinly, this one i created for a few failed files, however it can be combined with the previous function if needed.
# - **Process:**
#   - Skips lines with insufficient parts.
#   - Extracts Scopus ID, title, and link.
#   - Filters links to only those containing `www.sciencedirect.com`.
#   - Extracts the PII (Publisher Item Identifier) from the URL using regex and reconstructs a clean ScienceDirect article URL.
#   - Stores entries in a dictionary keyed by the cleaned title, with values containing Scopus ID and link.
# - **Batch Processing:** Multiple files are processed sequentially, and their dictionaries merged into a master dictionary `all_pdfs`.
# - **Outcome:** A consolidated dictionary of unique PDF entries keyed by title.
#
# ---
#
# #### 3. **Data Slicing and Cleaning**
#
# - **Function:** `slice_dict(d, start, end)` slices the dictionary to process manageable batches (e.g., first 2000 entries).
# - **Purpose:** Enables incremental processing and error isolation.
# - **Data Cleaning:**
#   - Reads an Excel file (`Remove_Scopus.xlsx`) containing Scopus IDs to exclude.
#   - Extracts IDs using regex and compares with batch IDs.
#   - Reports any overlaps to avoid processing unwanted or invalid entries.
#
# ---
#
# #### 4. **Automated PDF Downloading Using Safari and AppleScript**
#
# - **Functions:**
#   - `science_direct_open_pdf_in_safari_and_save(pdf_url)`: Automates Safari to open a PDF URL, simulate mouse clicks to trigger download, and close tabs.
#   - `clear_history()`: Clears Safari’s browsing history and cache to prevent interference or rate limiting.
#   - `new_tab()`: Opens new tabs in Safari to manage multiple downloads.
# - **Implementation Details:**
#   - Uses AppleScript executed via `osascript` to control Safari and system events.
#   - Coordinates mouse clicks at specific screen coordinates using `cliclick` (a command-line tool for mouse control).
#   - Includes delays to allow page loading and download completion.
# - **Platform:** macOS-specific automation leveraging Safari and system scripting.
#
# ---
#
# #### 5. **Handling Missing Downloads and File Management**
#
# - **Process:**
#   - Compares Scopus IDs in the batch with those already downloaded (by parsing filenames in the target folder).
#   - Identifies missing entries that need to be downloaded.
# - **Download Loop:**
#   - Iterates over missing entries.
#   - Periodically clears browser history and new tabs to maintain performance and avoid blocking.
#   - Downloads PDFs via the automated Safari script.
#   - Waits briefly to ensure download completion.
# - **File Renaming:**
#   - Renames downloaded PDFs using a sanitized version of the article title combined with the Scopus ID.
#   - Handles filename length issues by falling back to using only the Scopus.
# - **Error Handling:**
#   - Catches and logs exceptions during download and renaming to continue processing remaining entries.
#
# ---
#
# #### Strengths of the Pipeline
#
# - **Comprehensive Data Handling:** Supports both text and JSON input formats, enabling flexibility.
# - **Batch Processing:** Efficiently manages large datasets by slicing and incremental processing.
# - **Automated Browser Control:** Uses AppleScript and system tools to automate downloads without manual intervention.
# - **Duplicate and Error Management:** Checks for existing files to avoid redundant downloads and handles gracefully.
# - **Data Cleaning and Validation:** Cleans titles and URLs to maintain consistency and prevent errors.
#
# ---
#
# #### Potential Areas for Improvement
#
# - **Hardcoded Screen Coordinates:** The AppleScript relies on fixed mouse click positions, which may break if UI elements or screen resolution changes. Consider using UI scripting with element references or browser automation tools like Selenium for more robust control.
# - **Platform Dependency:** The current automation is macOS and Safari-specific. For cross-platform compatibility, consider browser automation frameworks.
# - **Download Verification:** Currently, the script assumes a PDF is downloaded if a new file appears in the Downloads folder. Adding checksum or file size verification could improve reliability.
#
# ---
#
# #### Summary
#
# This pipeline effectively automates the extraction, filtering, and downloading of academic PDFs from ScienceDirect using DOIs and metadata. It combines data parsing batch processing, and macOS automation to handle large-scale document retrieval with minimal manual effort. With some enhancements in robustness and scalability, it can serve as a powerful tool for researchers and librarians managing extensive digital collections.
#
# ---
#
# If you would like, I can also help design improvements, suggest alternative automation approaches, or assist with documentation and testing strategies. Let me know how you'd like to proceed!

# %%
import requests
from concurrent.futures import ThreadPoolExecutor
import subprocess
import time
import re
import pandas as pd
import numpy as np
import PyPDF2
import os
import ast
from tqdm import tqdm
from collections import OrderedDict
import os
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import subprocess
import time
import undetected_chromedriver as uc
import re

# %%
# https://www.sciencedirect.com/b/s/science/article/pii/S0925838824033462/pdfft?brr=93f2d3f3bcdcf00f&crasolve=1&r=93f2d3f22977f00f&ts=1747146355761&rtype=https&vrr=UKN&redir=UKN&redir_fr=UKN&redir_arc=UKN&vhash=UKN&host=d3d3LnNjaWVuY2VkaXJlY3QuY29t&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&rh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&re=X2JsYW5rXw%3D%3D&ns_h=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ns_e=X2JsYW5rXw%3D%3D&rh_fd=rrr%29n%5Ed%60i%5E%60_dm%60%5Eo%29%5Ejh&tsoh_fd=rrr%29n%5Ed%60i%5E%60_dm%60%5Eo%29%5Ejh&hc=%7Errr%29n%5Ed%60i%5E%60_dm%60%5Eo%29%5Ejhwrrr%29n%5Ed%60i%5E%60_dm%60%5Eo%29%5Ejhwrrr%29n%5Ed%60i%5E%60_dm%60%5Eo%29%5Ejh&iv=f95eb7d334876a04ed3e3be343b24c58&token=&text=...&original=3f697344544d52656469723d74727565&chkp=1c&rack=93f2d3f22977f00f

# %%
# https://pdf.sciencedirectassets.com/271090/1-s2.0-S0360544224X00195/1-s2.0-S0360544224033462/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEEYaCXVzLWVhc3QtMSJGMEQCIB19S0x%2FE39YZPK87zRpFiYc%2BfkN%2FjEFEvPyFGHJVWlIAiAiJ6QUTRYtR3gdLcnWBKHiQ2JPI5DeCpDEpujr%2Bnmk5Cq7BQjv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAUaDDA1OTAwMzU0Njg2NSIMlA4%2F1Ox0cTHtuuOiKo8F3T%2BJTei2f1GBU58Et7vxQeYKtKbnz9hcaPFmoNCtfIpD368vqFWWcgvhJa4%2BY3lP7%2BHeOs7lCI%2BQCq9m47SpXs%2F42gNvHrEMgYnaUg1r9Kd2Mu52u5LLWbFn5Ky%2BKMC5Snqt8cXCfoNectxfPVmrUQBg0ubxOJI5Xu6U6yh5jBw7t9%2F2DTCFXqmmNjAdgKQPrTqaPpn8hHusHi%2BALV5BddWtBonW289G04pExEjyfMCEpjHeyr%2F7uWe326L5zND4hYRD1xq5yi8jox%2BkePYgfbk4iipMcuHK9pEmx0jIuH77mn%2FxBtHShSZMag5j4qjovmawiI4wfRZ8V09466hwewXbkHEki9PmeizLK1PO6HahxhzZAqx5oXftyt6wDNZtLqFzC3n5Z%2FjsJwUYj66Fkt0gUvhoR7pb2EsrI6z2dZvr%2BoHj3bFuYRPFTcIQ%2F14aZYKMDSsKKqKrgnsSrxhZOpYoE7ssmdNZuIRMF39%2BVHszkny%2FjYiZFLtG8LTz69JwStdtnRFR7LrjYZRzRLZA8mgKkmny2BFGHUnGdG2VK5cKSDkPNOxLCQ4wX8YVPtibT5VGO7y0Ecst4S7O3Odw%2FPT84IBiv4OK8Qpv8KchBloYz44htEWCMui5HPewSkF5uf5Sztxf24b1LD4IhqcruSPM6u3MiS8pWzC9gd46xeQ4Ta3sZnblul59YomnvyLO1ryxRO1WBFhb%2FzYB62rm9ilop7rDEE7qW1rzsJjTA%2F7UyJ8V953%2FfoGyRazc7wLt611hY1uz2RPPCosgJz7ZhXqKho7d2vRGEO%2FyAA68vqxPrzf54RR4CWwGP%2F%2BiU8UQaNVWbaveHPYCe6A4yAMqxDxC6%2FMVWYDrFN0KL40ZjDDimY3BBjqyAek3iQHibCEFgTP9ORWL2jdnfclk5zb0FIeqfhhcvYGT7GrDHBsNyVBuSMgjSc9jG60s7q7HGcPY4Kl9VY1eP0ZsdnGUqC3CKCvEdETjXnXXV3u%2BLKVi3AZQmzvH%2B2rHWSS5ystwN7ykdnoct%2Bl9a6eFoK%2BXiO30lQI15Ze7VAwbY7Dbwvs2GrAcIVHBzwPDxCsxPRyiB33b4F83futEmzTM23MyD8ytGRGxC5VTO0YpEy8%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250513T141704Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTY26RKWYQY%2F20250513%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=8a0f8cece89f7804926cdaba33c38aa6b1e5e42fbeab89a3ec4721bb799bc8f8&hash=1f08cd0bb40f1c9038b51dc519d872112f391ab5c0ac27a3fdec5a69349b2024&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S0360544224033462&tid=spdf-f5752bb5-99ae-4065-bb74-37520d35f2ad&sid=24890c772493584c2b1b5c947f62c56076c3gxrqa&type=client&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&rh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ua=0f105752085c0d59080e&rr=93f2c6fa89a2f00f&cc=us

# %%
# https://www.sciencedirect.com/science/article/pii/S0360544224033474

# %%
def get_pdf_links_with_titles(file_path):
    pdf_dict = {}
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()
            if line.count(',') < 2:
                continue  # not enough parts, skip
            
            parts = line.split(',')
            scopus_id = parts[0].strip()
            link = parts[-1].strip() if parts[-1].strip() else None
            title = ','.join(parts[1:-1]).strip()  # join all parts between scopus_id and link
            
            if link and 'www.sciencedirect.com' in link.lower():
                m = re.search(r'/article/pii/([A-Za-z0-9]+)', link)
                if m:
                    pii = m.group(1)
                    link = f'https://www.sciencedirect.com/science/article/pii/{pii}'
                # Save with title as key
                pdf_dict[title] = {'scopus_id': scopus_id, 'link': link}
    
    return pdf_dict

if __name__ == "__main__":
    all_pdfs = {}
    
    file_paths = [
        './Downloads/retrieved_links_new/retrieved_links_140000-145000.txt',
        './Downloads/retrieved_links_new/retrieved_links_145000-150000.txt',
        './Downloads/retrieved_links_new/retrieved_links_150000-155000.txt',
        './Downloads/retrieved_links_new/retrieved_links_155000-160000.txt',
        './Downloads/retrieved_links_new/retrieved_links_160000-165000.txt',
        './Downloads/retrieved_links_new/retrieved_links_165000-170000.txt',
        './Downloads/retrieved_links_new/retrieved_links_170000-175000.txt',
        './Downloads/retrieved_links_new/retrieved_links_175000-180000.txt',
        './Downloads/retrieved_links_new/retrieved_links_180000-185000.txt',
        './Downloads/retrieved_links_new/retrieved_links_185000-190000.txt',
        './Downloads/retrieved_links_new/retrieved_links_190000-195000.txt',
        './Downloads/retrieved_links_new/retrieved_links_195000-200000.txt',
        './Downloads/retrieved_links_new/retrieved_links_200000-202947.txt'
    ]
    
    for path in file_paths:
        pdf_dict = get_pdf_links_with_titles(path)
        all_pdfs.update(pdf_dict)  # Merges new dict into main one

    print(f"Total unique PDF entries: {len(all_pdfs)}")
# Out:
# Total unique PDF entries: 7362

# %%
import re
import json

def get_pdf_links_with_titles(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)  # Load entire JSON as Python dict
    
    pdf_dict = {}

    for title, entry in data.items():
        link = entry.get("link", "")
        scopus_id = entry.get("scopus_id", "")

        if "pdf.sciencedirectassets.com" in link.lower():
            # Optionally fix the link
            link = link.replace('/b/', '/')
            pdf_dict[title] = {
                "scopus_id": scopus_id,
                "link": link
            }

    return pdf_dict



if __name__ == "__main__":
    all_pdfs = {}

    file_paths = [
        './Downloads/missing_entries_sciencedirect_1Jul.txt'
    ]
    
    for path in file_paths:
        pdf_dict = get_pdf_links_with_titles(path)
        all_pdfs.update(pdf_dict)  # Merges new dict into main one

    print(f"Total unique PDF entries: {len(all_pdfs)}")
# Out:
# Total unique PDF entries: 1624

# %%
def slice_dict(d, start, end):
    return dict(list(d.items())[start:end])

# %%
#  this is for a few entries containing NaN dois, hence if their IDs are found in Remove_Scopus.xlsx, just remove those IDs.

batch = slice_dict(all_pdfs, 0, 2000)
        
all_scopus_ids_in_data = {info['scopus_id'] for info in batch.values()}

remove_df = pd.read_excel('/Users/dtuser/Downloads/Remove_Scopus.xlsx')

# Extract SCOPUS IDs from Excel (assuming the column is named something like 'scopus_id')
remove_scopus_ids = set(remove_df.iloc[:, 1].astype(str).str.extract(r'SCOPUS_ID:(\d+)', expand=False).dropna())


# Check for overlap
overlap_ids = all_scopus_ids_in_data.intersection(remove_scopus_ids)

# Report result
if not overlap_ids:
    print("✅ No SCOPUS IDs in the batch are present in the Excel file.")
else:
    print(f"❌ {len(overlap_ids)} SCOPUS IDs found in both batch and Excel file.")
    print("Conflicting IDs:", overlap_ids)
# Out:
# ✅ No SCOPUS IDs in the batch are present in the Excel file.

# %%
def science_direct_open_pdf_in_safari_and_save(pdf_url):
    apple_script = f"""

    tell application "Safari"
    activate  -- Brings Safari to the front
    open location "{pdf_url}"
    delay 3 -- Wait for the page to load and for the PDF to render
    end tell
    
    tell application "System Events"
        tell process "Safari"
            set frontmost to true  -- Ensure Safari remains the active window
            delay 1
        end tell
    
        -- Click inside Safari to open the PDF
        do shell script "cliclick c:448,188"
        do shell script "cliclick c:445,153"
        delay 1
    
        -- Click the download button inside Safari
        delay 5
        do shell script "cliclick c:799,829"
        delay 1
    end tell
    
    tell application "Safari"
        activate
        tell front window
            close current tab
        end tell
    end tell
    
    tell application "Safari"
        activate
        tell front window
            close current tab
        end tell
    end tell
    """

    subprocess.run(["osascript", "-e", apple_script], text=True)

# %%
def clear_history():
    apple_script = """
    tell application "Safari"
        activate  -- Bring Safari to the front
    end tell

    delay 2  -- Give Safari time to come forward

    tell application "System Events"
        tell process "Safari"
            set frontmost to true  -- Ensure Safari remains the active window
            delay 1
        end tell

        -- Click at position 1
        do shell script "cliclick c:73,1"
        delay 1.5

        -- Click at position 2
        do shell script "cliclick c:115,196"
        delay 1.5

        -- Click at position 3
        do shell script "cliclick c:865,509"
        do shell script "cliclick c:865,509"
        do shell script "cliclick c:846,350"
        do shell script "cliclick c:846,350"
        delay 3
    end tell
    """

    import subprocess
    subprocess.run(["osascript", "-e", apple_script], text=True)

# %%
def new_tab():
    apple_script = """
    tell application "Safari"
        activate
        if not (exists window 1) then
            make new document
        else
            tell window 1
                make new tab
            end tell
        end if
    end tell
    """
    import subprocess
    subprocess.run(["osascript", "-e", apple_script], text=True)

# %%
clear_history()

# %%
next((i for i, (title, info) in enumerate(all_pdfs.items()) if info.get('scopus_id') == '85197488848'), None)
# Out:
# 3325

# %%
os.mkdir('/Users/dtuser/Downloads/sciencedirect_pdfs_28Jun-b2/')

# %%
# in first try, some entries maybe left out, so for that rerun for the same batch.

batch = slice_dict(all_pdfs, 0, 2000)

folder_path = '/Users/dtuser/Downloads/sciencedirect_pdfs_28Jun-b2/'

scopus_ids_in_folder = set()
for filename in os.listdir(folder_path):
    if '-' in filename:
        try:
            scopus_id_part = filename.rsplit('-', 1)[-1].split('.')[0]
            scopus_ids_in_folder.add(scopus_id_part)
        except IndexError:
            continue
    else:
        try:
            if int(filename[:-4]):
                scopus_id_part = filename[:-4]
                scopus_ids_in_folder.add(scopus_id_part)
        except:
            continue
        
all_scopus_ids_in_data = {info['scopus_id'] for info in batch.values()}

missing_scopus_ids = all_scopus_ids_in_data - scopus_ids_in_folder

missing_entries = {title: info for title, info in batch.items() if info['scopus_id'] in missing_scopus_ids}
len(scopus_ids_in_folder), len(missing_entries)
# Out:
# (0, 1624)

# %%
new_tab()
new_tab()
# Out:
# tab 5 of window id 147
# tab 6 of window id 147

# %%
download_path = '/Users/dtuser/Downloads/sciencedirect_pdfs_28Jun-b2/'
count = 0
clear_history()
for title, info in missing_entries.items():
    count += 1
    if count % 25 == 0:
        clear_history()
    if count % 30 == 0:
        new_tab()
        new_tab()
        new_tab()
        new_tab()
    link = info['link']
    scopus_id = info['scopus_id']
    try:
        science_direct_open_pdf_in_safari_and_save(link)
        time.sleep(2)
        files = os.listdir('./Downloads/')
        pdf_files = [f for f in files if f.endswith(".pdf")]
        current_time = time.time()
        recent_files = [
            os.path.join('', f)
            for f in pdf_files
            if current_time - os.path.getctime(os.path.join('./Downloads/', f)) <= 10
        ]
        
        if recent_files == []:
            continue
        safe_title = re.sub(r'</?inf>', '', title)
        safe_title = re.sub(r'[^A-Za-z0-9 ]+', '', safe_title)
        safe_title = safe_title.strip() + '-' + scopus_id
        new_name = os.path.join(download_path, f"{safe_title}.pdf")  # Rename with title
        latest_file = max([os.path.join('./Downloads', f) for f in recent_files], key=os.path.getctime)
        try:
            os.rename(latest_file, new_name)
            print(f"📂 Renamed file to: {new_name}")
        except OSError as e:
            if e.errno == 63:  
                fallback_name = os.path.join(download_path, f"{scopus_id}.pdf")
                os.rename(latest_file, fallback_name)
                print(f"⚠️ Filename too long, saved as: {fallback_name}")
            else:
                raise e  # Reraise other unexpected errors
        continue
    except Exception as e:
        print(f"❌ Error processing ScienceDirect PDF: {e}")
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 16
#      14 scopus_id = info['scopus_id']
#      15 try:
# ---> 16     science_direct_open_pdf_in_safari_and_save(link)
#      17     time.sleep(2)
#      18     files = os.listdir('./Downloads/')
#
# Cell In[8], line 42, in science_direct_open_pdf_in_safari_and_save(pdf_url)
#       1 def science_direct_open_pdf_in_safari_and_save(pdf_url):
#       2     apple_script = f"""
#       3
#       4     tell application "Safari"
#    (...)     39     end tell
#      40     """
# ---> 42     subprocess.run(["osascript", "-e", apple_script], text=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:552, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     550 with Popen(*popenargs, **kwargs) as process:
#     551     try:
# --> 552         stdout, stderr = process.communicate(input, timeout=timeout)
#     553     except TimeoutExpired as exc:
#     554         process.kill()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:1203, in Popen.communicate(self, input, timeout)
#    1201         stderr = self.stderr.read()
#    1202         self.stderr.close()
# -> 1203     self.wait()
#    1204 else:
#    1205     if timeout is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:1266, in Popen.wait(self, timeout)
#    1264     endtime = _time() + timeout
#    1265 try:
# -> 1266     return self._wait(timeout=timeout)
#    1267 except KeyboardInterrupt:
#    1268     # https://bugs.python.org/issue25942
#    1269     # The first keyboard interrupt waits briefly for the child to
#    1270     # exit under the common assumption that it also received the ^C
#    1271     # generated SIGINT and will exit rapidly.
#    1272     if timeout is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:2061, in Popen._wait(self, timeout)
#    2059 if self.returncode is not None:
#    2060     break  # Another thread waited.
# -> 2061 (pid, sts) = self._try_wait(0)
#    2062 # Check the pid and loop as waitpid has been known to
#    2063 # return 0 even without WNOHANG in odd situations.
#    2064 # http://bugs.python.org/issue14396.
#    2065 if pid == self.pid:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:2019, in Popen._try_wait(self, wait_flags)
#    2017 """All callers to this function MUST hold self._waitpid_lock."""
#    2018 try:
# -> 2019     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2020 except ChildProcessError:
#    2021     # This happens if SIGCLD is set to be ignored or waiting
#    2022     # for child processes has otherwise been disabled for our
#    2023     # process.  This child is dead, we can't get the status.
#    2024     pid = self.pid
#
# KeyboardInterrupt:

# %%
batch
# Out:
# {'Optimal allocation of renewable energy systems in a weak distribution network': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378779624005352',
#   'scopus_id': '85196938769'},
#  'Fabrication of yttriumdoped Li4SiO4 sorbents for CO2 capture and solar energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S0016236124014030',
#   'scopus_id': '85196934728'},
#  'Infrared nanoimaging and nanospectroscopy of electrochemical energy storage materials and interfaces': {'link': 'https://www.sciencedirect.com/science/article/pii/S2451910324001091',
#   'scopus_id': '85196830792'},
#  'Generative literature analysis on the rise of prosumers and their influence on the sustainable energy transition': {'link': 'https://www.sciencedirect.com/science/article/pii/S0957178724000924',
#   'scopus_id': '85196806789'},
#  'Tool for optimization of sale and storage of energy in wind farms': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378475423001167',
#   'scopus_id': '85151489159'},
#  'Multiobjective evolutionary method for multiarea dynamic emissioneconomic dispatch considering energy storage and renewable energy units': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024135074',
#   'scopus_id': '85204481419'},
#  'Options for environmental regulation policy under Chinas carbon peaking target Energy supply policy or carbon tax policy': {'link': 'https://www.sciencedirect.com/science/article/pii/S240584402414090X',
#   'scopus_id': '85204399618'},
#  'Economic analysis of hydrogen energy systems A global perspective': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024122505',
#   'scopus_id': '85204397075'},
#  'Impact of sustainable energy fossil fuels and green finance on ecosystem Evidence from China': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024127430',
#   'scopus_id': '85204172604'},
#  'Facile Biogenic synthesis of Europium doped lanthanum silicate nanoparticles as novel supercapacitor electrodes for efficient energy storage applications': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024139746',
#   'scopus_id': '85204039035'},
#  'Enhancing renewable energy utilization and energy management strategies for new energy yachts': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024138947',
#   'scopus_id': '85204033289'},
#  'Charting the path to sustainable prosperity Harnessing innovation renewable energy and institutional excellence for a greener tomorrow': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024138467',
#   'scopus_id': '85204026683'},
#  'Energy dissipation damage constitutive relation of CFRP passively confined coal sample': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024136171',
#   'scopus_id': '85203978673'},
#  'Exploring the impact of renewable energy green taxes and trade openness on carbon neutrality New insights from BRICS countries': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024130150',
#   'scopus_id': '85203666409'},
#  'Renewable energy regional tourism and exports to tackle stagnant growth in developed economies': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024132215',
#   'scopus_id': '85203644764'},
#  'Are hybrid approaches combining EKFUKF and artificial neural networks key to unlocking the full potential of sustainable energy technologies and reducing environmental footprint': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024127776',
#   'scopus_id': '85203417501'},
#  'Effect of superhigh water materials backfilling on stress decrease and energy release during strip coal pillar mining A case study': {'link': 'https://www.sciencedirect.com/science/article/pii/S240584402413472X',
#   'scopus_id': '85203417467'},
#  'Prioritization of renewable energy for offshore ship charging stations based on intuitionistic fuzzy GLDS method A case of China': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024125613',
#   'scopus_id': '85203407835'},
#  'A eutectic mixture catalyzed straight forward production of functional carbon from Sargassum tenerrimum for energy storage application': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378775324010024',
#   'scopus_id': '85199067452'},
#  'Evaluating the potential for solarplusstorage backup power in the United States as homes integrate efficient flexible and electrified energy technologies': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019546',
#   'scopus_id': '85197481550'},
#  'Combined daytime radiative cooling and solar photovoltaicthermal hybrid system for yearround energy saving in buildings': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019522',
#   'scopus_id': '85197363330'},
#  'Realtime automatic control of multienergy system for smart district community A coupling ensemble prediction model and safe deep reinforcement learning': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019832',
#   'scopus_id': '85197358283'},
#  'Comparative energy exergy and entropy generation study of a minichannel and a conventional solar flat plat collectors': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224020061',
#   'scopus_id': '85197354531'},
#  'Energy management of renewable energy connected electric vehicles charging using Internet of things Hybrid MRASDRN approach': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019029',
#   'scopus_id': '85197340306'},
#  'Organicinorganic hybrid phase change materials with high energy storage density based on porous shaped paraffinhydrated saltexpanded graphite composites': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019431',
#   'scopus_id': '85197337961'},
#  'Selected papers from the 5th European conference on supercritical CO2 for energy systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S036054422401836X',
#   'scopus_id': '85197169196'},
#  'Can renewable energy development facilitate Chinas sustainable energy transition Perspective from Energy Trilemma': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019340',
#   'scopus_id': '85197088285'},
#  'ROSMOSE A webbased decision support tool for the design and optimization of industrial and urban energy systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S036054422401956X',
#   'scopus_id': '85197068769'},
#  'A novel trigeneration energy system with two modes of operation for thermal energy storage and hydrogen production': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018954',
#   'scopus_id': '85197065839'},
#  'System reliability study of geothermal energy walls in subway stations based on rapid thermal performance prediction model': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224020164',
#   'scopus_id': '85196953930'},
#  'Revealing electricity conversion mechanism of a cascade energy storage system': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019200',
#   'scopus_id': '85196800507'},
#  'Progress and challenges of latent thermal energy storage through external fielddependent heat transfer enhancement methods': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018759',
#   'scopus_id': '85196747608'},
#  'Assessing and analysing energy system balance A decision tree approach': {'link': 'https://www.sciencedirect.com/science/article/pii/S036054422401675X',
#   'scopus_id': '85196736144'},
#  'An experimental investigation of a solar chimney integrated with a bladeless wind turbine for sustainable energy harvesting': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019285',
#   'scopus_id': '85196636696'},
#  'Design and operation of an adiabatic compressed air energy storage system incorporating a detailed heat exchanger model': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018784',
#   'scopus_id': '85196634429'},
#  'Tecnoeconoenvirosocial assessment of clean electrification for a marine equipment manufacturing plant in Trkiye through hybrid renewable energy system with demand response': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224017894',
#   'scopus_id': '85196525511'},
#  'Investigating the influence of erratic grid on stationary battery energy storage technologies in hybrid power systems Technoenvironeconomic perspectives': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019145',
#   'scopus_id': '85196516248'},
#  'Solar photovoltaic refrigeration system coupled with a flexible costeffective and highenergydensity chemisorption cold energy storage module': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019376',
#   'scopus_id': '85196485830'},
#  'Biomimetic swallowtail Vshaped attachments for enhanced lowspeed wind energy harvesting by a galloping piezoelectric energy harvester': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018371',
#   'scopus_id': '85196485829'},
#  'A globalized methodology of energysaving solar greenhouse design in high latitudes': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224024563',
#   'scopus_id': '85196479632'},
#  'Distributed restoration for integrated electricitygasheating energy systems with an iterative loop scheme': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018255',
#   'scopus_id': '85196427979'},
#  'From exergoeconomics to ThermoX Optimization in the transition to sustainable energy systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018127',
#   'scopus_id': '85196424259'},
#  'Integrating relational values in social acceptance of photovoltaic energy storage systems A consumers perspective assessment using structural equation modeling': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018668',
#   'scopus_id': '85196393151'},
#  'Renewable exergy return on investment RExROI in energy systems The case of silicon photovoltaic panels': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224017341',
#   'scopus_id': '85196324010'},
#  'Integrating blockchain and strategic alliance in renewable energy supply chain toward sustainability A comparative decision framework under uncertainty': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019108',
#   'scopus_id': '85196302267'},
#  'Optimal energy management based on realtime performance analysis for the solid oxide fuel cellcombined heat and power system': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018401',
#   'scopus_id': '85196291119'},
#  'Solar energy modelling and proposed crops for different types of agrivoltaics systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018486',
#   'scopus_id': '85196290410'},
#  'Efficient Coordination of Renewable Energy Resources through Optimal Reversible Pumped HydroStorage Integration for Autonomous Microgrid Economic Operation': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224016839',
#   'scopus_id': '85196266357'},
#  'Tracking the provincial energy transition in China A comprehensive index': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224016529',
#   'scopus_id': '85196266258'},
#  'Land use efficiency and energy transition in Chinese cities A clusterfrontier superefficiency SBMbased analytical approach': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018231',
#   'scopus_id': '85196196280'},
#  'Optimum design of Chinese solar greenhouses for maximum energy availability': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224017535',
#   'scopus_id': '85196038278'},
#  'A multistage twolayer stochastic design model for integrated energy systems considering multiple uncertainties': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224015020',
#   'scopus_id': '85196016131'},
#  'Innovative ecofriendly design solutions for energy demands using swirl induced burner by jets': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224016736',
#   'scopus_id': '85195855705'},
#  'Optimal multiobjective sizing of renewable energy sources and battery energy storage systems for formation of a multimicrogrid system considering diverse load patterns': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224016943',
#   'scopus_id': '85195842579'},
#  'Effect of wind conditions on the performance of an Oscillating Water Column energy converter': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224017353',
#   'scopus_id': '85195814046'},
#  'Performance analysis of a new compressed air energy storage system coupled with the municipal solid waste power generation systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224017997',
#   'scopus_id': '85195797616'},
#  'Determining Weibull distribution patterns for wind conditions in building energyefficient design across the different thermal design zones in China': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224017870',
#   'scopus_id': '85195781968'},
#  'Research on investment selection of parklevel integrated energy system considering electricityheatcoolingstorage based on matter element extension': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224018280',
#   'scopus_id': '85195776922'},
#  'Wake effect impact on the levelized cost of energy in large floating offshore wind farms A case of study in the northwest of the Iberian Peninsula': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360544224019339',
#   'scopus_id': '85195200955'},
#  'Stable energy storage performance at hightemperature of PESUbased dielectric composite regulated by SiO2 and BNNSs': {'link': 'https://www.sciencedirect.com/science/article/pii/S0266353824003087',
#   'scopus_id': '85198034440'},
#  'Developing a novel sustainable and durable selfluminous pavement material with solar energy absorption capability': {'link': 'https://www.sciencedirect.com/science/article/pii/S0950061824030769',
#   'scopus_id': '85201200246'},
#  'Fuzzy logicbased coordinated operation strategy for an offgrid photovoltaic hydrogen production system with batterysupercapacitor hybrid energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360319924033469',
#   'scopus_id': '85201586005'},
#  'Optimizing a hybrid solid oxide fuel cellgas turbine and geothermal energy system for enhanced efficiency and economic performance in power and hydrogen production scenario': {'link': 'https://www.sciencedirect.com/science/article/pii/S036031992403355X',
#   'scopus_id': '85201513227'},
#  'Modeling and manufacturing of solar modules of different designs for energy supply of biogas plant': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360319924032804',
#   'scopus_id': '85201489927'},
#  'Cost and CO2 emissions cooptimisation of green hydrogen production in a gridconnected renewable energy system': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360319924032142',
#   'scopus_id': '85201472106'},
#  'Integrating green hydrogen production with renewable energypowered desalination An analysis of CAPEX implications and operational strategies': {'link': 'https://www.sciencedirect.com/science/article/pii/S036031992403413X',
#   'scopus_id': '85201465734'},
#  'Energy storage and electrocatalytic performance of selfsupported NiCo2O4CoFeLDHNF coreshell nanostructured material': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360319924034050',
#   'scopus_id': '85201194516'},
#  'Hydrogen foam flooding for integrated oil recovery and clean energy storage in depleted reservoirs': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624029433',
#   'scopus_id': '85202355597'},
#  'AIbased data mining approach to control the environmental impact of conventional energy technologies': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624029226',
#   'scopus_id': '85202353150'},
#  'Exploring the willingness and evolutionary process of public participation in community shared energy storage projects Evidence from four firsttier cities in China': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624029111',
#   'scopus_id': '85202208752'},
#  'Comprehensive assessment of waste heat recovery mismatch and renewable energy integration in data centers A multifaceted energy economic and environmental perspectives': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624029159',
#   'scopus_id': '85202024047'},
#  'Recycling of waste edible oil derivatives as phase change materials for building energy conservation': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624029007',
#   'scopus_id': '85201897357'},
#  'A Novel AgMgFe2O4 nanocomposite based hydroelectric cell Green energy source illuminating the future': {'link': 'https://www.sciencedirect.com/science/article/pii/S0925838824016190',
#   'scopus_id': '85195268698'},
#  'Sustainability evaluation of C3MR natural gas liquefaction process Integrating life cycle analysis with Energy Exergy and economic aspects': {'link': 'https://www.sciencedirect.com/science/article/pii/S1226086X24003472',
#   'scopus_id': '85194089665'},
#  'Onestep synthesis and fabrication of ZrMo2O8 nanostructures as advanced electrode material for energy storage applications': {'link': 'https://www.sciencedirect.com/science/article/pii/S1226086X24001527',
#   'scopus_id': '85187393649'},
#  'Seasonal hydrogen energy storage sizing Twostage economicsafety optimization for integrated energy systems in northwest China': {'link': 'https://www.sciencedirect.com/science/article/pii/S2589004224019163',
#   'scopus_id': '85205294261'},
#  'Thermodynamic analysis of a combined heating and power plant hybrid with compressed air energy storage and molten salt heat storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027609',
#   'scopus_id': '85201073381'},
#  'Green building material with superior thermal insulation and energy storage properties fabricated by Paraffin and foam cement composite': {'link': 'https://www.sciencedirect.com/science/article/pii/S095006182402871X',
#   'scopus_id': '85200999578'},
#  'Activated nitrogendoped porous carbon from organic solid waste to energy storage materials Pore structure forming and Ndoping paths from recent methods': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027671',
#   'scopus_id': '85200802855'},
#  'Numerical investigations on performance improvement of molten saltbased horizontal latent heat thermal energy storage unit with optimized structures': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027890',
#   'scopus_id': '85200649206'},
#  'Chemically exfoliated fewlayer phthalocyaninebased covalent organic frameworks used as improved energy storage electrode for lithiumion batteries': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027105',
#   'scopus_id': '85200600202'},
#  'Photovoltaic integrated optimized energy storage drives for electric vehicles': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026847',
#   'scopus_id': '85200535275'},
#  'Coordination in islanded microgrids Integration of distributed generation energy storage system and load shedding using a new decentralized control architecture': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027853',
#   'scopus_id': '85200462620'},
#  'Impact of filler size and shape on performance of thermal energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027439',
#   'scopus_id': '85200343271'},
#  'Solar thermal energy and CO2 storage in saline aquifers for renewable energy space heating': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027932',
#   'scopus_id': '85200270805'},
#  'Multiagent consistent cost optimization for hybrid energy system': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027452',
#   'scopus_id': '85200244739'},
#  'An adaptive inertial matching strategy with accurately balancing energy storage system state of charge in distributed DC microgrid': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X2402680X',
#   'scopus_id': '85200244096'},
#  'Profit distribution through blockchain solution from battery energy storage system in a virtual power plant using intelligence techniques': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027361',
#   'scopus_id': '85200243058'},
#  'Optimising gridforming inverters to prevent underfrequency load shedding with minimal energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24024289',
#   'scopus_id': '85200155134'},
#  'Quick charging adsorptionbased thermal energy storage system': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026835',
#   'scopus_id': '85200140009'},
#  'A hybrid model for packed bed thermal energy storage system': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026549',
#   'scopus_id': '85199995254'},
#  'Advanced ceramics in energy storage applications Batteries to hydrogen energy': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027087',
#   'scopus_id': '85199971343'},
#  'High Coulombic efficiency driven by tortuosity gradient regulation for highperformance biomass carbon energy storage materials': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027488',
#   'scopus_id': '85199964623'},
#  'A multiobjective analysis of gridconnected local renewable energy systems for industrial SMEs': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026197',
#   'scopus_id': '85199963812'},
#  'Improved multiobjective differential evolution algorithm and its application in the capacity configuration of urban rail photovoltaic hybrid energy storage systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027415',
#   'scopus_id': '85199958222'},
#  'Capacity expansion model for multitemporal energy storage in renewable energy base considering various transmission utilization rates': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027312',
#   'scopus_id': '85199952971'},
#  'Influence of Nidoping on CuCo2O4 electrode for enhanced supercapacitor performance and sustainable energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027373',
#   'scopus_id': '85199949348'},
#  'Energy storage and melting heat transfer of coconut oilCuO aluminum open cell composite embedded in a double wavy wall cavity': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24024617',
#   'scopus_id': '85199946521'},
#  'Nanomaterial based composite phase change materials and nanofluid for solar thermal energy storage applications Featuring numerical and experimental approaches': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026185',
#   'scopus_id': '85199942467'},
#  'An improved microgrid energy management system based on hybrid energy storage system using ANN NARMAL2 controller': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026823',
#   'scopus_id': '85199928385'},
#  'Development and characterization of PVAbased nanocomposites with graphene and natural quartz nanoparticles for energy storage applications': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027245',
#   'scopus_id': '85199922295'},
#  'Sustainable synthesis of facile Bi2O3Sb2O4ZrO nanocomposite as electrode material for energy storage and bifunctional electrocatalyst for energy generation': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24027476',
#   'scopus_id': '85199878228'},
#  'Geometrical and PCM optimization of a thermocline energy storage system': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026562',
#   'scopus_id': '85199795832'},
#  'Integrating insulated concrete form ICF with solardriven reverse osmosis desalination for building integrated energy storage in cold climates': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X2402718X',
#   'scopus_id': '85199781098'},
#  'Technoeconomic analysis of implementing pumped hydro energy storage to store solar and wind energy in waterstressed areas': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026100',
#   'scopus_id': '85199709729'},
#  'Distributionally robust dispatch of power system with advanced adiabatic compressed air energy storage for frequency security': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24023685',
#   'scopus_id': '85199701993'},
#  'Ecofriendly preparation of nickel cobaltite as an electrode material in sustainable energy storage devices': {'link': 'https://www.sciencedirect.com/science/article/pii/S001346862400896X',
#   'scopus_id': '85199064935'},
#  'Synergistic advancements in energy storage gC3N4NiFe2O4PANI composite with augmented electrochemical capabilities': {'link': 'https://www.sciencedirect.com/science/article/pii/S0013468624009502',
#   'scopus_id': '85198910107'},
#  'Optimal integration of hybrid renewable energy systems for decarbonized urban electrification and hydrogen mobility': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360319924032063',
#   'scopus_id': '85201381329'},
#  'Improvement of azobenzene photothermal energy storage density via grafting onto gC3N4 and introducing hydrogen bonding': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360319924032373',
#   'scopus_id': '85201126301'},
#  'Multiobjective robust dynamic pricing and operation strategy optimization for integrated energy system based on stackelberg game': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360319924031203',
#   'scopus_id': '85201065996'},
#  'Parasitismpredation optimization algorithmbased energy management system for hybrid electric power system': {'link': 'https://www.sciencedirect.com/science/article/pii/S0360319924032956',
#   'scopus_id': '85200941067'},
#  'Latent thermal energy storage using solidstate phase transformation in caloric materials': {'link': 'https://www.sciencedirect.com/science/article/pii/S2666386424004600',
#   'scopus_id': '85203972669'},
#  'Synthesis of reduced graphene oxide rGOpolyaniline PANI composite electrode for energy storage Aqueous asymmetric supercapacitor': {'link': 'https://www.sciencedirect.com/science/article/pii/S001430572400627X',
#   'scopus_id': '85200249141'},
#  'Optimizing service networks to support freight rail decarbonization Flow selection facility location and energy sourcing': {'link': 'https://www.sciencedirect.com/science/article/pii/S0377221724002868',
#   'scopus_id': '85190838105'},
#  'Green innovation imperative for natural resourcedriven sustainable economic recovery Linking rights Structure corporate social responsibility and renewable energy contracts': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024129702',
#   'scopus_id': '85203248676'},
#  'Modeling sustainable photocatalytic degradation of acidic dyes using Jordanian nanoKaolinTiO2 and solar energy Synergetic mechanistic insights': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024130095',
#   'scopus_id': '85203163629'},
#  'Assessing the impact of water scarcity on thermoelectric and hydroelectric potential and electricity price under climate change Implications for future energy management': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024129015',
#   'scopus_id': '85203122044'},
#  'Perceptions of biomass energy sustainability in policy scenarios of China': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024132112',
#   'scopus_id': '85203021360'},
#  'Thermal and mechanical performance assessment of composite CPCM for energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024132434',
#   'scopus_id': '85202788906'},
#  'Advanced AI and renewable energy sources for unified rotor angle stability control': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024124863',
#   'scopus_id': '85202756000'},
#  'Towards sustainable development Examining renewable energy consumption in E7 countries': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024126734',
#   'scopus_id': '85202699385'},
#  'A comprehensive study on energy management sensitivity analysis and inertia compliance of feedin tariff in IEEE bus systems with gridconnected renewable energy sources': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024129581',
#   'scopus_id': '85202669637'},
#  'COVID19 impact on wind and solar energy sector and cost of energy prediction based on machine learning': {'link': 'https://www.sciencedirect.com/science/article/pii/S240584402412693X',
#   'scopus_id': '85202651048'},
#  'Optimization research on control strategies for photovoltaic energy storage systems considering multimode operation': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024129830',
#   'scopus_id': '85202497692'},
#  'Optimizing energy management strategies for microgrids through chaotic local search and particle swarm optimization techniques': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024127004',
#   'scopus_id': '85202151172'},
#  'Constructing renewable energy sphere for efficient search': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624028610',
#   'scopus_id': '85202066407'},
#  'Mixedinteger disciplined convex programming approach applied to the optimal energy supply of nearzero energy buildings': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024129040',
#   'scopus_id': '85202033009'},
#  'The effect of ecofriendly and financial technologies on renewable energy growth in emerging economies': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024126722',
#   'scopus_id': '85202015551'},
#  'Integration of thermal energy storage for sustainable energy hubs in the forest industry A comprehensive analysis of cost thermodynamic efficiency and availability': {'link': 'https://www.sciencedirect.com/science/article/pii/S2405844024125509',
#   'scopus_id': '85201867385'},
#  'Enhancing concentrated photovoltaic power generation efficiency and stability through liquid air energy storage and cooling utilization': {'link': 'https://www.sciencedirect.com/science/article/pii/S0038092X2400570X',
#   'scopus_id': '85201781877'},
#  'Maximizing solar energy efficiency with efficient interleaved boost converter with ThreeLevel neutral point clamped inverter for GridConnected photovoltaic using hybrid approach': {'link': 'https://www.sciencedirect.com/science/article/pii/S0038092X24005504',
#   'scopus_id': '85201731459'},
#  'A novel and costeffective model for cloud energy storage based on a dual storage setup in active distribution grid with resilience consideration': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624028816',
#   'scopus_id': '85201672721'},
#  'Study of phase Stability Optical and thermoelectric properties of antiperovskites X3GeO XCa Sr Ba for solar cells and energy harvesting': {'link': 'https://www.sciencedirect.com/science/article/pii/S0038092X24005589',
#   'scopus_id': '85201641751'},
#  'A shapestable phase change material for hightemperature thermal energy storage based on coal fly ash and Na2SO4K2SO4': {'link': 'https://www.sciencedirect.com/science/article/pii/S0038092X24005632',
#   'scopus_id': '85201612494'},
#  'Technicaleconomic analysis and optimization of multiple effect distillation system by solar energy conversion as the heat source': {'link': 'https://www.sciencedirect.com/science/article/pii/S0038092X24005541',
#   'scopus_id': '85201508515'},
#  'Performance comparison of largescale thermal energy storage and hydrogen as seasonal storage for achieving energy autarky in residential districts with different renovation levels': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24025957',
#   'scopus_id': '85200704731'},
#  'Metalorganic frameworks and their composites Design synthesis properties and energy storage applications': {'link': 'https://www.sciencedirect.com/science/article/pii/S1385894724057838',
#   'scopus_id': '85199972390'},
#  'Assessment of energy economic and environmental aspects of the methanolfueled Allam cycle in crossborder renewable energy supply chain': {'link': 'https://www.sciencedirect.com/science/article/pii/S0196890424007957',
#   'scopus_id': '85199956195'},
#  'A comprehensive review of liquid piston compressed air energy storage for sustainable renewable energy integration': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026574',
#   'scopus_id': '85199862875'},
#  'Life cycle analysis of hydrogen production by different alkaline electrolyser technologies sourced with renewable energy': {'link': 'https://www.sciencedirect.com/science/article/pii/S0196890424007817',
#   'scopus_id': '85199756144'},
#  'Economic evaluation of the seconduse batteries energy storage system considering the quantification of environmental benefits': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026744',
#   'scopus_id': '85199719874'},
#  'A steam combination extraction thermal energy storage scheme in boiler side for coalfired power plant flexibility retrofit': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026240',
#   'scopus_id': '85199718038'},
#  'Numerical investigation of the effect of eccentricity on the melting performance of a rotating triplextube latent heat energy storage system': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026045',
#   'scopus_id': '85199693919'},
#  'Hierarchical CosbndNi layered double hydroxide nanosheets enwrapped CuO nanorods by electrodeposition for excellent energy storage devices': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24025829',
#   'scopus_id': '85199564815'},
#  'A novel reducedcommunication control strategy for multiobjective energy management of DC microgrids considering battery storage systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24024678',
#   'scopus_id': '85199560878'},
#  'A multiobjective collaborative planning method for a PVpowered hybrid energy system considering sourceload matching': {'link': 'https://www.sciencedirect.com/science/article/pii/S0196890424007891',
#   'scopus_id': '85199511205'},
#  'Numerical study of an energy storage unit based on zeolitewater adsorption for mobilized thermal energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026781',
#   'scopus_id': '85199479685'},
#  'Optimal planning of multitype renewable energy resources and electric vehicle charging stations under resilient charging tariff using Gorilla Troops optimizer': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24024940',
#   'scopus_id': '85199460464'},
#  'Review of innovative design and application of hydraulic compressed air energy storage technology': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026173',
#   'scopus_id': '85199457984'},
#  'Boosted energy storage densities in leadfree Na05Bi05TiO3based thick film ceramics via the compositional and microstructural tailoring': {'link': 'https://www.sciencedirect.com/science/article/pii/S1385894724055360',
#   'scopus_id': '85199453798'},
#  '3D carbon based phase change composites A review on progress in fabrication strategies thermal energy storageconversion efficacy prototypes numerical models and applications': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X2402615X',
#   'scopus_id': '85199447712'},
#  'Scheduling optimization of shared energy storage and peertopeer power trading among industrial buildings': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824006558',
#   'scopus_id': '85199443550'},
#  'A comprehensive review of geothermal energy storage Methods and applications': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026057',
#   'scopus_id': '85199423042'},
#  'FeLiNO3TiN comodified MgO for enhanced thermochemical energy storage performance in MgOMgOH2 cycles': {'link': 'https://www.sciencedirect.com/science/article/pii/S1385894724054809',
#   'scopus_id': '85199410358'},
#  'Stability thermal and solidification behaviour of oxygen functionalized GNPsCuOwaterbased hybrid nanofluid phase change materials for cool thermal energy storage system': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026938',
#   'scopus_id': '85199400179'},
#  'Construction of sulfur modified oxygendeficient NiONi nanoflakes as an effective electrode material for energy storage application': {'link': 'https://www.sciencedirect.com/science/article/pii/S1385894724056511',
#   'scopus_id': '85199395814'},
#  'Optimal configuration of hydrogen energy storage in an integrated energy system considering variable hydrogen production efficiency': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026306',
#   'scopus_id': '85199368491'},
#  'A method of cyclic icing and melting for stable and rapid formation of hydrate Novel strategy of hydratebased energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24024253',
#   'scopus_id': '85199286100'},
#  'New approach for zero energy industries via integrating energy management and renewable energy system Enviroeconomic investigation': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824006893',
#   'scopus_id': '85199281679'},
#  'A comprehensive review on building integrated phase change floors with phase change materials for energy storage and indoor environment control': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24025143',
#   'scopus_id': '85199267016'},
#  'Thermal performance of a high temperature flat plate thermal energy storage unit with multiple phase change materials': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24025891',
#   'scopus_id': '85199261476'},
#  'Transitioning weathered oil fields towards new energy A review on utilizing hydrogenotrophic methanogens for petroleum hydrocarbons remediation': {'link': 'https://www.sciencedirect.com/science/article/pii/S0304389424018582',
#   'scopus_id': '85199256632'},
#  'Impact of temporal resolution on the design and reliability of residential energy systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824005279',
#   'scopus_id': '85199254565'},
#  'Capability of batterybased integrated renewable energy systems in the energy management and flexibility regulation of smart distribution networks considering energy and flexibility markets': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24025933',
#   'scopus_id': '85199252405'},
#  'Excellent lowE energy storage and fluorescence temperature sensing features in Bi05Na05TiO3based transparent ceramics': {'link': 'https://www.sciencedirect.com/science/article/pii/S1385894724056390',
#   'scopus_id': '85199209318'},
#  'Interface engineering of polymer composite films for hightemperature capacitive energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S1385894724055451',
#   'scopus_id': '85199174099'},
#  'Evaluation of performance energy and exergy analysis of a solar parabolic dish collector connected to a dryer with nanofluid and PCM': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24025556',
#   'scopus_id': '85199149537'},
#  'Electrocatalytically active and charged natural chalcopyrite for nitratecontaminated wastewater purification extended to energy storage ZnNO3supsup battery': {'link': 'https://www.sciencedirect.com/science/article/pii/S0304389424018661',
#   'scopus_id': '85199143436'},
#  'Repurposing hazardous waste material into energy storage system': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24026148',
#   'scopus_id': '85199129949'},
#  'Comparing different parameter identification techniques for optimal control of building energy systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824006790',
#   'scopus_id': '85199053984'},
#  'Promoting solar energy utilization Prediction analysis and evaluation of solar radiation on building surfaces at city scale': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824006777',
#   'scopus_id': '85198955344'},
#  'Printed MXeneNiSe asymmetric microsupercapacitors for flexible energy storage devices': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24024174',
#   'scopus_id': '85198902408'},
#  'Wide temperature range phase change cold energy storage by using esterification between polyethylene glycol and lauric acid': {'link': 'https://www.sciencedirect.com/science/article/pii/S1385894724054949',
#   'scopus_id': '85198746515'},
#  'Exploring the effects of interdependencies on energy systems in smart communities A multidomain modeling and quasiMonte Carlo sensitivity analysis': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824006261',
#   'scopus_id': '85198719255'},
#  'Defect engineering and insitu electrochemical oxidation promote lattice reconstruction of VO2 for boosting the energy storage of aqueous zincion batteries': {'link': 'https://www.sciencedirect.com/science/article/pii/S1385894724051167',
#   'scopus_id': '85198707566'},
#  'Energy demand and air quality in social housing buildings A novel critical review': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824006583',
#   'scopus_id': '85198596715'},
#  'High performance nanoenhanced phase change composites based on 2hydroxyethylamonium stearate for efficient and environmentally friendly thermal energy storage and thermoelectric conversion': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378775324009947',
#   'scopus_id': '85198579287'},
#  'Giant mechanical energy storage capacity and longterm mechanical cyclability in a finegrained Heuslertype Co51V33Ga16 shape memory alloy': {'link': 'https://www.sciencedirect.com/science/article/pii/S1359645424005366',
#   'scopus_id': '85198511987'},
#  'Impact of uncertainty in building operation patterns and electric energy demand on the design and technoeconomic performance of solar photovoltaic systems in different climates': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824006029',
#   'scopus_id': '85198300705'},
#  'Selfpowered frostresistant and antimicrobial hydrogel with high opencircuit voltage for flexible device energy supply and stimuli feedback': {'link': 'https://www.sciencedirect.com/science/article/pii/S1385894724054226',
#   'scopus_id': '85198288899'},
#  'Multicriteria optimization of electrode materials for anion exchange membrane water electrolysis regarding energy demand and material criticality': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378775324009832',
#   'scopus_id': '85198034096'},
#  'Structural electron spin resonance electrochemical energy storage and cytotoxicity properties of CeO2ZnFe2O4 nanocomposites': {'link': 'https://www.sciencedirect.com/science/article/pii/S0254058424007727',
#   'scopus_id': '85198018232'},
#  'Rheological aspects of solidtoliquid phase transitions in paraffin waxbitumen blends for thermal energy storage applications': {'link': 'https://www.sciencedirect.com/science/article/pii/S1359431124014479',
#   'scopus_id': '85197876309'},
#  'Experimental results and upscaling assessment of a costefficient macroencapsulated latent heat energy storage system for heat pumps': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824006121',
#   'scopus_id': '85197816905'},
#  'Nitrogen configuration modulation of porous graphitic carbon nanosheets for superior capacitive energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378775324009790',
#   'scopus_id': '85197778739'},
#  'Performance analysis of PEMFCassisted renewable energy source heat pumps as a novel active system for plus energy buildings': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824005930',
#   'scopus_id': '85197770259'},
#  'Recycling food waste to agriculture through hydrothermal carbonization sustains foodenergywater nexus': {'link': 'https://www.sciencedirect.com/science/article/pii/S1385894724051994',
#   'scopus_id': '85197518993'},
#  'Modeling a solar shading system that controls heat gain by using solar energy to change louver slat angles': {'link': 'https://www.sciencedirect.com/science/article/pii/S0378778824006340',
#   'scopus_id': '85197505895'},
#  'A prospective review on the design and operation of integrated energy system The spotlight cast on dynamic characteristics': {'link': 'https://www.sciencedirect.com/science/article/pii/S1359431124014194',
#   'scopus_id': '85197361005'},
#  'Structureactivity relationship between pore morphology and thermochemical energy storage properties based on MgCO3MgO': {'link': 'https://www.sciencedirect.com/science/article/pii/S0927024824003398',
#   'scopus_id': '85197352781'},
#  'Optimization of guide plates and orifice plates on thermal management of battery energy storage system': {'link': 'https://www.sciencedirect.com/science/article/pii/S1359431124014625',
#   'scopus_id': '85197018916'},
#  'Performance evaluation on a novel split thermoelectric system driven by solar energy for electric vehicle seats': {'link': 'https://www.sciencedirect.com/science/article/pii/S1359431124014698',
#   'scopus_id': '85196871160'},
#  'Vibration control and energy harvesting of offshore wind turbines installed with TMDI under dynamical loading': {'link': 'https://www.sciencedirect.com/science/article/pii/S0141029624010216',
#   'scopus_id': '85196764238'},
#  'Enhancing the performance of parabolic trough solar collectors Costeffective innovative designs for sustainable energy harvesting': {'link': 'https://www.sciencedirect.com/science/article/pii/S1359431124013619',
#   'scopus_id': '85196665077'},
#  'Urban energy transition in renewable energy management considering policy and law challenges and opportunities in the pursuit of clean and sustainable urban environments': {'link': 'https://www.sciencedirect.com/science/article/pii/S2210670724003457',
#   'scopus_id': '85196495454'},
#  'Flexibility analysis on absorptionbased carbon capture integrated with energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S0016236124014273',
#   'scopus_id': '85196395922'},
#  'Optimal sizing of PVWind generators with a smart EV charging framework to build grid friendly Net Zero Energy Campus': {'link': 'https://www.sciencedirect.com/science/article/pii/S2210670724004001',
#   'scopus_id': '85196036711'},
#  'Interface engineering of SnO2 to enhance the cycle stability of WO3 and Prussian blue for complementary electrochromic smart windows and energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S0272884224025598',
#   'scopus_id': '85196022849'},
#  'Theoretical exploration of PtSSeZrS2 Van der Waals heterostructure for solar energy conversion': {'link': 'https://www.sciencedirect.com/science/article/pii/S0921452624005064',
#   'scopus_id': '85195837405'},
#  'The integration of NiCo oxidephosphidesulphide composites into nanowire arrays on Ni foam as supercapacitor electrode for boosting energy storage performance': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24025441',
#   'scopus_id': '85198514394'},
#  'Fast power correction based transient frequency response strategy for energy storage system in lowinertia power systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X24025416',
#   'scopus_id': '85198508775'},
# ...
#   'scopus_id': '85200401700'},
#  'LFC of smart interconnected power system in the presence of renewable energy sources using coordinated control design of hybrid electric vehicles': {'link': 'https://www.sciencedirect.com/science/article/pii/S1755008424000735',
#   'scopus_id': '85200384321'},
#  'G20 roadmap for carbon neutrality The role of Paris agreement artificial intelligence and energy transition in changing geopolitical landscape': {'link': 'https://www.sciencedirect.com/science/article/pii/S0301479724020668',
#   'scopus_id': '85200321864'},
#  'Exploring macro patenting trends and key technological components in offshore wind energy': {'link': 'https://www.sciencedirect.com/science/article/pii/S0172219024000401',
#   'scopus_id': '85200315121'},
#  'Elasticacoustic optical and thermoelectric investigation of Cu6AsS5X X Br I for renewable energy applications': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352214324000686',
#   'scopus_id': '85200238639'},
#  'Unpacking the environmental quality through the effects of natural resources renewable energy consumption banking development and industrial value addition An empirical evidence from BRICS countries': {'link': 'https://www.sciencedirect.com/science/article/pii/S0301479724022072',
#   'scopus_id': '85200225008'},
#  'Optimized flow rate and efficient shaft water cooling method for EVs PMSM temperaturedependent energy system output power increase': {'link': 'https://www.sciencedirect.com/science/article/pii/S2214157X24009328',
#   'scopus_id': '85200223591'},
#  'Orange Citrus sinensis essential oil inclusion in highenergy diets for feedlot lambs productivity eating behavior carcass characteristics rumen morphometry and fatty acid profile of the meat': {'link': 'https://www.sciencedirect.com/science/article/pii/S0921448824001329',
#   'scopus_id': '85200214589'},
#  'Domestic hot water solar thermal systems as an energysecurity alternative in the EU A parametric analysis': {'link': 'https://www.sciencedirect.com/science/article/pii/S2213138824003175',
#   'scopus_id': '85200157072'},
#  'Graphene nanoplateletsinfused binary eutectic phase change materials for enhanced thermal energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S2589234724002707',
#   'scopus_id': '85200142818'},
#  'Asymmetric impacts of climate policy uncertainty investor sentiment on energy prices and renewable energy consumption Evidence from NARDL and wavelet coherence': {'link': 'https://www.sciencedirect.com/science/article/pii/S0301479724020437',
#   'scopus_id': '85200120886'},
#  'Investigating the asymmetric impact of artificial intelligence on renewable energy under climate policy uncertainty': {'link': 'https://www.sciencedirect.com/science/article/pii/S0140988324005176',
#   'scopus_id': '85200120169'},
#  'Mapping of the levelised cost of energy from floating solar PV in coastal waters of the European Atlantic North Sea and Baltic Sea': {'link': 'https://www.sciencedirect.com/science/article/pii/S0038092X24005048',
#   'scopus_id': '85200118365'},
#  'Detailed modeling of droopcontrolled multienergy systems under unbalanced operation': {'link': 'https://www.sciencedirect.com/science/article/pii/S235246772400208X',
#   'scopus_id': '85200116467'},
#  'Enhanced hybrid energy storage system combining battery and supercapacitor to extend nanosatellite lifespan': {'link': 'https://www.sciencedirect.com/science/article/pii/S2590123024008892',
#   'scopus_id': '85200115759'},
#  'The energy transition paradox How lithium extraction puts pressure on environment society and politics': {'link': 'https://www.sciencedirect.com/science/article/pii/S2214790X24000960',
#   'scopus_id': '85200110327'},
#  'Climate policy stringency and trade in energy transition minerals An analysis of response patterns': {'link': 'https://www.sciencedirect.com/science/article/pii/S0301420724006032',
#   'scopus_id': '85200107653'},
#  'Numerical and experimental studies of a novel integrated photothermal system to utilize solar fullspectrum energy': {'link': 'https://www.sciencedirect.com/science/article/pii/S0038092X24005103',
#   'scopus_id': '85200106121'},
#  'Extreme mixing in nanoporous highentropy oxides for highly durable energy storage': {'link': 'https://www.sciencedirect.com/science/article/pii/S2468519424003355',
#   'scopus_id': '85199996530'},
#  'Incorporating public perception of Renewable Energy Landscapes in local spatial planning tools A case study in Mediterranean countries': {'link': 'https://www.sciencedirect.com/science/article/pii/S0143622824001632',
#   'scopus_id': '85199961085'},
#  'Enhancing the integration of PV and coalfired power plant for lowcarbon lowcost and reliable power supply through various energy storage systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S2213138824003205',
#   'scopus_id': '85199957330'},
#  'Solar salt encapsulated into 3D printed activated carbonalumina supports for thermal energy storage applications': {'link': 'https://www.sciencedirect.com/science/article/pii/S2666539524001123',
#   'scopus_id': '85199950742'},
#  'Sensitivity analysis of borehole thermal energy storage BTES examining key factors for system optimization': {'link': 'https://www.sciencedirect.com/science/article/pii/S2772683524000487',
#   'scopus_id': '85199949666'},
#  'Wateraccommodated fractions of crude oil and its mixture with chemical dispersant impairs oxidase stress and energy metabolism disorders in Oryzias melastigma embryos': {'link': 'https://www.sciencedirect.com/science/article/pii/S004565352401806X',
#   'scopus_id': '85199943966'},
#  'Tuning the composition of manganese cobaltite spinel with tungsten for enhanced energy storage performance': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352507X24001902',
#   'scopus_id': '85199942016'},
#  'Highlyefficient singlelevel robust transmission expansion planning approach applicable to largescale renewable energy integration': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352467724002157',
#   'scopus_id': '85199938109'},
#  'Synergizing renewable energy sources in buildingintegrated hybrid energy systems via nicheant colony optimization': {'link': 'https://www.sciencedirect.com/science/article/pii/S2214157X24009110',
#   'scopus_id': '85199908427'},
#  'Studying the impact of investments in critical minerals and energy transition in transportation sector in Asia': {'link': 'https://www.sciencedirect.com/science/article/pii/S0301420724005944',
#   'scopus_id': '85199905867'},
#  'Characterization of energydriven damage mechanism and gas seepage in coal under mininginduced stress conditions': {'link': 'https://www.sciencedirect.com/science/article/pii/S1365160924001990',
#   'scopus_id': '85199892103'},
#  'Transitions to deeply decarbonized transportation and energy systems around the world challenges and solutions': {'link': 'https://www.sciencedirect.com/science/article/pii/S1361920924001767',
#   'scopus_id': '85199875014'},
#  'Digitizing the green revolution Ecommerce as a catalyst for clean energy transition in rural China': {'link': 'https://www.sciencedirect.com/science/article/pii/S0140988324004869',
#   'scopus_id': '85199760746'},
#  'Dynamic linkages and contagion effects Analyzing the linkages between crude oil prices US market sector indices and energy markets': {'link': 'https://www.sciencedirect.com/science/article/pii/S1062940824001724',
#   'scopus_id': '85199674831'},
#  'Maximizing energy transfer of solarbattery charge controller using voltage balancing strategy': {'link': 'https://www.sciencedirect.com/science/article/pii/S2590123024008594',
#   'scopus_id': '85199535877'},
#  'Melting performance improvement of phase change materials with thermal energy storage unit using nanoparticles': {'link': 'https://www.sciencedirect.com/science/article/pii/S2214157X24009237',
#   'scopus_id': '85199533807'},
#  'Design update of DEMO BOP for HCPB BB concept with an energy storage system': {'link': 'https://www.sciencedirect.com/science/article/pii/S0920379624004617',
#   'scopus_id': '85199512979'},
#  'A prospective assessment of scale effects of energy conversion in ultralowhead pumped hydro energy storage units': {'link': 'https://www.sciencedirect.com/science/article/pii/S0196890424007398',
#   'scopus_id': '85199502296'},
#  'The United Kingdom electricity market mechanism A tool for a battery energy storage system optimal dispatching': {'link': 'https://www.sciencedirect.com/science/article/pii/S0960148124010255',
#   'scopus_id': '85199497345'},
#  'A multidimensional sensitivity analysis approach for evaluating the robustness of renewable energy sources in European countries': {'link': 'https://www.sciencedirect.com/science/article/pii/S095965262402674X',
#   'scopus_id': '85199489813'},
#  'A synthetic analysis of postconstruction displacement and attraction of marine birds at offshore wind energy installations': {'link': 'https://www.sciencedirect.com/science/article/pii/S0195925524001987',
#   'scopus_id': '85199416238'},
#  'A comprehensive review of green hydrogen energy systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S0960148124009790',
#   'scopus_id': '85199387741'},
#  'Can China avoid the energy trilemma in achieving carbon peak A dynamic scenario forecasting study based on energy transition': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624026581',
#   'scopus_id': '85199308781'},
#  'Experimental Study on the Characteristics of Energy Accumulation before Peak in Coal Rock Combinations with Different Dip Angles': {'link': 'https://www.sciencedirect.com/science/article/pii/S1226798825001588',
#   'scopus_id': '85199298158'},
#  'Energy and exergy analysis of an innovative solar system for hydrothermal carbonization process using photovoltaic solar panels': {'link': 'https://www.sciencedirect.com/science/article/pii/S0960148124010322',
#   'scopus_id': '85199261104'},
#  '105 MW molten salt furnace experimental investigation of fullconditional thermal energy storage for the transfer and storage of waste heat from blast furnace gas': {'link': 'https://www.sciencedirect.com/science/article/pii/S0960148124010231',
#   'scopus_id': '85199168018'},
#  'Analysis of power generation considering design and finishing materials of thermoelectric energy harvesting blocks': {'link': 'https://www.sciencedirect.com/science/article/pii/S0960148124011091',
#   'scopus_id': '85199162807'},
#  'Thermal stability mechanism and operating temperature limit of molten chloride salts for thermal energy storage and concentrated solar power applications': {'link': 'https://www.sciencedirect.com/science/article/pii/S0960148124011054',
#   'scopus_id': '85199158794'},
#  'Multidimensional analysis in optimal sizing of hybrid renewable energy systems for green energy growth in Garoua Cameroon From technoeconomic and social models to policies': {'link': 'https://www.sciencedirect.com/science/article/pii/S0196890424007453',
#   'scopus_id': '85199154015'},
#  'Retraction notice to Experimental investigation on sustainable cycling of thermochemical energy storage CaOH2CaO using a pressurized air flow J Clean Prod 439 2024 140925S095965262400372X101016jjclepro2024140925': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624026088',
#   'scopus_id': '85199149697'},
#  'TechnoEconomic Modeling and Safe Operational Optimization of MultiNetwork Constrained Integrated Community Energy Systems': {'link': 'https://www.sciencedirect.com/science/article/pii/S2666792424000210',
#   'scopus_id': '85199108418'},
#  'Research and economic evaluation on novel pulse superconducting magnet power supply topology with energy storage for fusion devices': {'link': 'https://www.sciencedirect.com/science/article/pii/S0920379624004514',
#   'scopus_id': '85199098269'},
#  'An offgrid hybrid renewable energy solution in remote Doomadgee of Far North Queensland Australia Optimisation technosocioenviroeconomic analysis and multivariate polynomial regression': {'link': 'https://www.sciencedirect.com/science/article/pii/S0960148124010590',
#   'scopus_id': '85199096058'},
#  'Prediction of heat transfer characteristics and energy efficiency of a PVT solar collector with corrugatedtube absorber using artificial neural network and group method data handling models': {'link': 'https://www.sciencedirect.com/science/article/pii/S0735193324005918',
#   'scopus_id': '85199086911'},
#  'Performance study of a compressed air energy storage system incorporating abandoned oil wells as air storage tank': {'link': 'https://www.sciencedirect.com/science/article/pii/S2214157X24008074',
#   'scopus_id': '85199078464'},
#  'Agrophotovoltaics enhancing solar land use efficiency for energy food water nexus': {'link': 'https://www.sciencedirect.com/science/article/pii/S1755008424000644',
#   'scopus_id': '85199022637'},
#  'Datadriven based financial analysis of concentrated solar power integrating biomass and thermal energy storage A profitability perspective': {'link': 'https://www.sciencedirect.com/science/article/pii/S0961953424002599',
#   'scopus_id': '85198984751'},
#  'The dual role of lowcarbon ammonia in climatesmart farming and energy transition': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624026374',
#   'scopus_id': '85198979231'},
#  'Impact of forecasting on energy system optimization': {'link': 'https://www.sciencedirect.com/science/article/pii/S2666792424000192',
#   'scopus_id': '85198966743'},
#  'An integrated nodal price for distribution networks to facilitate cost recovery and renewable energy promotion': {'link': 'https://www.sciencedirect.com/science/article/pii/S014206152400320X',
#   'scopus_id': '85198958000'},
#  'Flexibilitybased operation and construction of energy hub considering battery aging and DeepLearning for participation in demand response programs': {'link': 'https://www.sciencedirect.com/science/article/pii/S0196890424007441',
#   'scopus_id': '85198925194'},
#  'Are exports a push or drag to Chinas carbon constraint targets Evidence from the new energy technologyrare earth industry chain': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624026349',
#   'scopus_id': '85198913803'},
#  'Optimizing government strategy for deep decarbonization in towns A game theory approach incorporating energy storage services': {'link': 'https://www.sciencedirect.com/science/article/pii/S0959652624025563',
#   'scopus_id': '85198903390'},
#  'The pathway towards decarbonisation and netzero emissions by 2050 The role of solar energy technology': {'link': 'https://www.sciencedirect.com/science/article/pii/S2949736124000344',
#   'scopus_id': '85198851313'},
#  'Exploring the potential of decentralized renewable energy conversion systems on water energy and food security in africa': {'link': 'https://www.sciencedirect.com/science/article/pii/S0196890424006988',
#   'scopus_id': '85198753461'},
#  'Renewable energy communities and mitigation of energy poverty Instruments for policymakers and community managers': {'link': 'https://www.sciencedirect.com/science/article/pii/S2352467724002005',
#   'scopus_id': '85198741461'},
#  'Forecasting patenting areas with academic paper amp patent data A wind power energy case': {'link': 'https://www.sciencedirect.com/science/article/pii/S0172219024000371',
#   'scopus_id': '85198733511'},
#  'Modeling a 100 renewable energy pathway in developing Countries A case study of State of Goa India': {'link': 'https://www.sciencedirect.com/science/article/pii/S0196890424007416',
#   'scopus_id': '85198732225'},
#  'Optimal scheduling of smart home energy systems A userfriendly and adaptive home intelligent agent with selflearning capability': {'link': 'https://www.sciencedirect.com/science/article/pii/S2666792424000209',
#   'scopus_id': '85198602352'},
#  'Theoretical study on salt hydrates adsorption desalination system using solar and waste energy with and without heat recovery': {'link': 'https://www.sciencedirect.com/science/article/pii/S2213138824002960',
#   'scopus_id': '85198584730'}}
